# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("https://raw.githubusercontent.com/marsja/jupyter/master/SimData/Data_to_Transform.csv")

# %%
df.head()
# Out:
#    Moderate Positive Skew  Highly Positive Skew  Moderate Negative Skew  \
# 0                0.899990              2.895074               11.180748
# 1                1.113554              2.962385               10.842938
# 2                1.156830              2.966378               10.817934
# 3                1.264131              3.000324               10.764570
# 4                1.323914              3.012109               10.753117
#
#    Highly Negative Skew
# 0              9.027485
# 1              9.009762
# 2              9.006134
# 3              9.000125
# 4              8.981296

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 6), sharey=True)
fig.suptitle('histplot of norma distributed data & Zscores of that data')

sns.histplot(df['Moderate Positive Skew'],ax=axes[0,0], kde=True)
sns.histplot(df['Highly Positive Skew'],ax=axes[0,1],kde=True)
sns.histplot(df['Moderate Negative Skew'],ax=axes[1,0],kde=True)
sns.histplot(df['Highly Negative Skew'],ax=axes[1,1],kde=True)
plt.show()

# %% [markdown]
# ## Fisher-Pearson coefficient of skewness
#     As rule of thumb, skewness can be interpreted like this:
#
#         Skewness Fairly Symmetrical -0.5 to 0.5
#         Moderate Skewed -0.5 to -1.0 and 0.5 to 1.0
#         Highly Skewed < -1.0 and > 1.0

# %%
df.agg(['skew']).T
# Out:
#                             skew
# Moderate Positive Skew  0.656308
# Highly Positive Skew    1.271249
# Moderate Negative Skew -0.690244
# Highly Negative Skew   -1.201891

# %%
df['Highly Negative Skew'].skew()
# Out:
# -1.2018914074077787

# %% [markdown]
# ## kurtosis

# %%
df.agg(['kurtosis']).T
# Out:
#                         kurtosis
# Moderate Positive Skew  0.584120
# Highly Positive Skew    2.405999
# Moderate Negative Skew  0.790534
# Highly Negative Skew    2.086863

# %% [markdown]
# ### methods to calcuate Fisher-Pearson coefficient of skewness

# %%
3*(df['Highly Negative Skew'].mean()-df['Highly Negative Skew'].median())/df['Highly Negative Skew'].std()
# Out:
# -0.5811196345742645

# %%
#The sample skewness is computed as the Fisher-Pearson coefficient of skewness

series = df['Highly Negative Skew']
n = len(series)
skew = series.sub(series.mean()).div(series.std(ddof=0)).apply(lambda x: x ** 3).mean()
skew * (n * (n - 1)) ** 0.5 / (n - 1)
# Out:
# -1.2017712062469146

# %%
import scipy.stats.stats as stats
print (stats.skew(series, bias=False))
# Out:
# -1.2018914074077784

# %%
plt.figure(figsize=(12,2))
sns.histplot(df['Highly Positive Skew'], kde=True)
plt.show()
plt.figure(figsize=(12,2))
sns.boxplot(x=df['Highly Positive Skew'],orient = ["h"])
plt.show()

# %%
sns.boxplot(x=df['Highly Positive Skew'])
# Out:
# <AxesSubplot:xlabel='Highly Positive Skew'>

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 6))
fig.suptitle('Horizontally stacked subplots')
plt.grid()
ax1.hist(df['Highly Positive Skew'], bins=30)
ax2.boxplot(df['Highly Positive Skew'])
plt.show()

# %%
fig, ax = plt.subplots(4, 2, figsize=(10, 28))
fig.suptitle('Highly Positive Skew & Highly Negative Skew')
ax[0,0].hist(df['Highly Positive Skew'], bins=30)
ax[0,1].boxplot(df['Highly Positive Skew'])
ax[1,0].hist(df['Highly Negative Skew'], bins=30)
ax[1,1].boxplot(df['Highly Negative Skew'])
ax[2,0].hist(df['Moderate Positive Skew'], bins=30)
ax[2,1].boxplot(df['Moderate Positive Skew'])
ax[3,0].hist(df['Moderate Negative Skew'], bins=30)
ax[3,1].boxplot(df['Moderate Negative Skew'])
plt.show()

# %%
plt.figure(figsize=(12,2))
sns.boxplot(x=df['Highly Positive Skew'],orient = ["h"])
plt.show()
plt.figure(figsize=(12,2))
sns.boxplot(x=df['Moderate Positive Skew'],orient = ["h"])
plt.show()
plt.figure(figsize=(12,2))
sns.boxplot(x=df['Highly Negative Skew'],orient = ["h"])
plt.show()
plt.figure(figsize=(12,2))
sns.boxplot(x=df['Moderate Negative Skew'],orient = ["h"])
plt.show()

# %%
a = df.columns.values

# %%
a
# Out:
# array(['Moderate Positive Skew', 'Highly Positive Skew',
#        'Moderate Negative Skew', 'Highly Negative Skew'], dtype=object)

# %%
columns = df.columns.values
for i in columns:
    plt.figure(figsize=(12,2))
    sns.histplot(df[i], kde=True)
    plt.show()
    plt.figure(figsize=(12,2))
    sns.boxplot(x=df[i],orient = ["h"])
    plt.show()

# %%
normal_data = np.random.normal(20,5,10000)
plt.figure(figsize=(12,2))
sns.histplot(normal_data, kde=True)
plt.show()
plt.figure(figsize=(12,2))
sns.boxplot(x=normal_data,orient = ["h"])
plt.show()

# %%
df
# Out:
#       Moderate Positive Skew  Highly Positive Skew  Moderate Negative Skew  \
# 0                   0.899990              2.895074               11.180748
# 1                   1.113554              2.962385               10.842938
# 2                   1.156830              2.966378               10.817934
# 3                   1.264131              3.000324               10.764570
# 4                   1.323914              3.012109               10.753117
# ...                      ...                   ...                     ...
# 9995               14.749050             16.289513               -2.980821
# 9996               14.854474             16.396252               -3.147526
# 9997               15.262103             17.102991               -3.517256
# 9998               15.269983             17.628467               -4.689833
# 9999               16.204517             18.052331               -6.335679
#
#       Highly Negative Skew
# 0                 9.027485
# ...

# %% [markdown]
# ## Q-Q plot:
# The q-q (Quantile-to-Quantile) plot is used to compare the quantiles of two distributions. The quantiles can be defined as continuous intervals with equal probabilities or dividing the samples between a similar way The distributions may be theoretical or sample distributions from a process, etc. The normal probability plot is a case of the q-q plot. Normal Probability plot: The normal probability plot is a way of knowing whether the dataset is normally distributed or not. In this plot, data is plotted against the theoretical normal distribution plot in a way such that if a given dataset is normally distributed it should form an approximate straight line. The normal probability plot is a case of the probability plot (more specifically Q-Q plot). This plot is commonly used in the industry for finding the deviation from the normal process.

# %%
import scipy.stats as sc
import statsmodels.graphics.gofplots as sm

fig, ax = plt.subplots(1, 2, figsize=(9, 5))
sm.ProbPlot(normal_data).qqplot(line='s', ax=ax[1]);
sns.histplot(normal_data,kde=True, color ='blue',ax=ax[0])
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
columns = df.columns.values
for i in columns:
    fig, ax = plt.subplots(1, 2, figsize=(8,4))
    fig.suptitle(i)
    sm.ProbPlot(df[i]).qqplot(line='s', ax=ax[1]);
    sns.histplot(normal_data,kde=True, color ='blue',ax=ax[0])
    plt.show()

# %%
df.loc[0:4]
# Out:
#    Moderate Positive Skew  Highly Positive Skew  Moderate Negative Skew  \
# 0                0.899990              2.895074               11.180748
# 1                1.113554              2.962385               10.842938
# 2                1.156830              2.966378               10.817934
# 3                1.264131              3.000324               10.764570
# 4                1.323914              3.012109               10.753117
#
#    Highly Negative Skew
# 0              9.027485
# 1              9.009762
# 2              9.006134
# 3              9.000125
# 4              8.981296

# %%
df.iloc[:,0]
# Out:
# 0        0.899990
# 1        1.113554
# 2        1.156830
# 3        1.264131
# 4        1.323914
#           ...
# 9995    14.749050
# 9996    14.854474
# 9997    15.262103
# 9998    15.269983
# 9999    16.204517
# Name: Moderate Positive Skew, Length: 10000, dtype: float64

# %% [markdown]
# # Transformation of skewed distribution back to normal distribution

# %%
dff= pd.DataFrame()
dff['Highly Positive Skew']=df['Highly Positive Skew']

# %% [markdown]
# ### sqrt operation

# %%
dff['sqrt']=np.sqrt(df.iloc[:,0])

# %%
dff
# Out:
#       Highly Positive Skew      sqrt
# 0                 2.895074  0.948678
# 1                 2.962385  1.055251
# 2                 2.966378  1.075560
# 3                 3.000324  1.124336
# 4                 3.012109  1.150615
# ...                    ...       ...
# 9995             16.289513  3.840449
# 9996             16.396252  3.854150
# 9997             17.102991  3.906674
# 9998             17.628467  3.907683
# 9999             18.052331  4.025483
#
# [10000 rows x 2 columns]

# %% [markdown]
# ### log operation

# %%
dff['D_log'] = np.log(max(df.iloc[:, 2] + 1) - df.iloc[:, 2])

# %%
dff['D_log2'] = np.log(df.iloc[:,0])

# %% [markdown]
# ### boxcox transformation
#     the Box-Cox transformation also requires our data to only contain positive numbers so if we want to apply it on negatively skewed data we need to reverse it (see the previous examples on how to reverse your distribution). If we try to use boxcox() on the column “Moderate Negative Skewed”, for example, we get a ValueError. More exactly, if you get the “ValueError: Data must be positive” while using either np.sqrt(), np.log() or SciPy’s boxcox() it is because your dependent variable contains negative numbers. To solve this, you can reverse the distribution.

# %%
from scipy.stats import boxcox
dff['boxcox'] =boxcox(df.iloc[:, 0])[0]

# %%
dff
# Out:
#       Highly Positive Skew      sqrt     D_log    D_log2    boxcox
# 0                 2.895074  0.948678  0.000000 -0.105371 -0.103432
# 1                 2.962385  1.055251  0.291034  0.107557  0.109628
# 2                 2.966378  1.075560  0.309552  0.145684  0.149502
# 3                 3.000324  1.124336  0.347962  0.234385  0.244374
# 4                 3.012109  1.150615  0.356016  0.280593  0.294988
# ...                    ...       ...       ...       ...       ...
# 9995             16.289513  3.840449  2.718764  2.691179  4.496676
# 9996             16.396252  3.854150  2.729699  2.698301  4.515148
# 9997             17.102991  3.906674  2.753534  2.725373  4.585788
# 9998             17.628467  3.907683  2.825571  2.725889  4.587141
# 9999             18.052331  4.025483  2.918658  2.785290  4.744558
#
# [10000 rows x 5 columns]

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
columns = dff.columns.values
for i in columns:
    fig, ax = plt.subplots(1, 2, figsize=(8,4))
    fig.suptitle(i)
    sm.ProbPlot(dff[i]).qqplot(line='s', ax=ax[1]);
    sns.histplot(normal_data,kde=True, color ='blue',ax=ax[0])
    plt.show()

# %%
dff.agg(['skew', 'kurtosis']).transpose()
# Out:
#                           skew  kurtosis
# Highly Positive Skew  1.271249  2.405999
# sqrt                  0.152479 -0.001163
# D_log                -0.361324  0.408754
# D_log2               -0.392229  0.377312
# boxcox                0.000155 -0.003519
